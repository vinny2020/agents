# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# xaymaca@gmail.com
# www.linkedin.com/in/
# vincentstoessel (LinkedIn)
# github.com/vinny2020 (Personal)
# Top Skills
# Google Gemini
# Azure
# Grafana
# Languages
# English (Native or Bilingual)
# Certifications
# Learning How to Learn: Powerful
# mental tools to help you master
# tough subjects
# Honors-Awards
# Backbase Certified Back-End
# Engineer for the 5.6 Platform
# Vincent Stoessel
# Senior Software Engineer @ Backbase | Spring Boot & Cloud | AI-
# Augmented Engineering | Microsoft Alum
# Atlanta, Georgia, United States
# Summary
# Software engineering is not just my profession; it's my passion. I am
# a dedicated and solutions-oriented Senior Software Engineer with
# 14 years of experience in software design, project management,
# and cloud-native architectures. Adept in framework tools, DevOps
# practices, and continuous integration, I ensure streamlined
# development processes and deliver robust, reliable solutions. As a
# proactive leader and creative problem-solver, I foster collaborative
# environments that drive successful project outcomes.
# Experience
# Backbase
# Senior Software Engineer (Fintech)
# March 2025 - Present (11 months)
# Atlanta, Georgia, United States
# Development of Digital Banking Solutions: I am part of a team aiming to create
# the best digital banking solution on the planet, enabling our clients to deliver
# superior online and mobile customer experiences.
# Microsoft
# 3 years 7 months
# Senior Software Engineer (Security)
# July 2021 - January 2025 (3 years 7 months)
# Atlanta, Georgia, United States
# Enhanced MDTI's Microsoft Graph endpoints by implementing new features
# and resolving technical issues. Authored and updated Microsoft Graph API
# documentation, contributing to the open-source GitHub repository.
# Developed and maintained features, addressed bugs, conducted pull
# request reviews, and deployed updates for the Microsoft Defender for Threat
# Intelligence (MDTI) application as a full-stack developer.
#   Page 1 of 4
# Utilized Java and Spring Boot for backend development and React for frontend
# UI implementation.
# Performed on-call responsibilities, including monitoring and responding to
# incidents via the Incident Response system. Have created and presented Post
# Incident Reviews (PIR) for the leadership team (LT).
# Ensured GDPR compliance by maintaining data classification standards for
# data privacy.
# Senior Site Reliability Engineer (Security)
# July 2021 - July 2023 (2 years 1 month)
# Atlanta, Georgia, United States
# Led a cross-organizational project to integrate a multi-level detection
# authoring framework and hosting service with a security information and event
# management (SIEM) into the Azure China Sovereign Cloud.
# Engineered real-time AI/ML inference capabilities by collaborating with
# data scientists to develop an Azure Function that streamed live data into
# an AzureML model. Optimized Kusto Query Language (KQL) queries and
# provisioned essential infrastructure, ensuring synchronized data delivery for
# accurate, live predictions
# Collaborated with air-gapped Government Cloud engineering teams to ensure
# feature parity with public consumer clouds and compliance with regulatory
# standards.
# Developed and Tested new deployment pipelines and Azure Resource
# Management (ARM) templates for critical security information and event
# management (SIEM) services.
# Atlanta Java Users Group
# Board Member, DevNexus chair
# May 2010 - October 2022 (12 years 6 months)
# Greater Atlanta Area
# Board member of the Java Users Group and co-organizer for the annual
# DevNexus, the largest Java conference in the US. Helps organize the free
# monthly Java based meetup group.
# Backbase
# Senior Software Engineer
#   Page 2 of 4
# March 2017 - July 2021 (4 years 5 months)
# Atlanta, Georgia, United States
# Worked within Backbase to help build and support modern banking solutions
# for Financial Institutions from around the globe. We helped them modernize
# so they could face the disruption from challenger banks and fintechs. My stack
# included Java, Spring Microservices, Docker, Spring Cloud and other Cloud
# Native tools that were deployed to both AWS and Azure
# Manheim
# Senior Messaging Engineer
# September 2016 - March 2017 (7 months)
# Greater Atlanta Area
# Developed, Supported, Tested and Deployed ActiveMQ Clustered Messaging
# Systems.
# Used Java to help develop enhanced capabilities into the existing ActiveMQ
# cluster.
# Leveraged the Apache Camel Java DSL to increase application flexibility.
# Provided Level 3 on-call support for the existing ActiveMQ cluster. Learned
# and built custom RPMs with spec files and rpmbuild.
# Deploy message brokers to VM based test environments via Puppet. Built
# monitoring dashboards using Splunk Cloud. Monitored and did troubleshooting
# of upstream messaging issues with various internal teams.
# Backbase
# Java Integration Engineer
# October 2014 - September 2016 (2 years)
# Atlanta
# My primary role was to integrate the core Backbase platform with internal and
# external services in order to support our clients.  I've implemented solutions
# using Docker, Apache Camel, Apache CXF (SOAP), ActiveMQ, Velocity,
# Jackson, Spring, OSGi and the list goes on. I work closely with the team in
# Amsterdam as well as the Frontend developers here in the US. Occasional
# travel throughout the US and Europe.
# Forbes Travel Guide
# Architect, Senior Developer
# January 2013 - October 2014 (1 year 10 months)
# Atlanta, Ga
# Forbes Travel Guide was a spinoff company from Sharecare/Arnold Media
# LLC.
#   Page 3 of 4
# As a member of the Forbes Travel Guide team, I joined the new venture with
# most of my original team.
# Responsible for designing and coding the overarching features for our core
# framework.
# Got up to speed quickly with MongoDB as we transitioned away from Riak.
# Investigated new technologies and frameworks for future usage.
# Helped lay the foundation for porting a poorly designed, legacy
# ColdFusion B2B application to a modern Grails based solution.
# (Forbeshospitalitysolutions.com)
# Ran a bi-weekly “code meetup” with developers to discuss best practices and
# the current state of the codebase.
# Maintained code for Magnolia CMS,  including making a change in the
# datastore implementation that was instrumental in saving the company
# 72,000USD annually.
# Sharecare, Inc
# Engineering Team Lead (Health Care)
# May 2011 - January 2013 (1 year 9 months)
# Atlanta, Georgia, United States
# One of the first engineers  hired for the new startup venture. Helped to build
# and mentor a new development team coming from various backgrounds
# I was a coding team lead, developing software as I attempted to lead by
# example.
# Learned and implemented Scrum as our Agile methodology.
# Got up to speed quickly with the Riak NoSQL datastore. Worked
# on the software platform that powered both Sharecare.com and
# Forbestravelguide.com. Was assigned the role of leading the Forbes Travel
# Guide development team.
# We brought the Forbes Travel Guide’s luxury travel site up and running with a
# hard deadline of 6 months from inception.
# Leveraged the java skills of the team to build a robust Spring MVC and
# Magnolia CMS based development platform that was reusable across two of
# the company's marquee sites. Sharecare.com and Forbestravelguide.com
# Education
# University of Maryland Baltimore County
# BA, Economics
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Vincent Stoessel"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Vincent Stoessel. You are answering questions on Vincent Stoessel's website, particularly questions related to Vincent Stoessel's career, background, skills and experience. Your responsibility is to represent Vincent Stoessel for interactions on the website as faithfully as possible. You are given a summary of Vincent Stoessel's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Vincent Stoessel. I'm an entrepreneur, software engineer and AI enthusiast. I'm originally from New York, but I moved to Atlanta in 2006.\nI love all foods, particularly Jamaican food and anything curry based like Thai and Indian foods.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nxaymaca@gmail.com\nwww.linkedin.com/in/\nvincentstoessel (LinkedIn)\ngithub.com/vinny2020 (Personal)\nTop Skills\nGoogle Gemini\nAzure\nGrafana\nLanguages\nEnglish (Native or Bilingual)\nCertifications\nLearning How to Learn: Powerful\nmental tools to help you master\ntough subjects\nHonors-Awards\nBackbase Certified Back-End\nEngineer for the 5.6 Platform\nVincent Stoessel\nSenior Software Engineer @ Backbase | Spring Boot & Cloud | AI-\nAugmented Engineering | Microsoft Alum\nAtlanta, Georgia, United States\nSummary\nSoftware engineering is not just my profession; it's my passion. I am\na dedicated and solutions-oriented Senior Software Engineer with\n14 years of experience in software design, project management,\nand cloud-native architectures. Adept in framework tools, DevOps\npractices, and continuous integration, I ensure streamlined\ndevelopment processes and deliver robust, reliable solutions. As a\nproactive leader and creative problem-solver, I foster collaborative\nenvironments that drive successful project outcomes.\nExperience\nBackbase\nSenior Software Engineer (Fintech) \nMarch 2025\xa0-\xa0Present\xa0(11 months)\nAtlanta, Georgia, United States\nDevelopment of Digital Banking Solutions: I am part of a team aiming to create\nthe best digital banking solution on the planet, enabling our clients to deliver\nsuperior online and mobile customer experiences.\nMicrosoft\n3 years 7 months\nSenior Software Engineer (Security)\nJuly 2021\xa0-\xa0January 2025\xa0(3 years 7 months)\nAtlanta, Georgia, United States\nEnhanced MDTI's Microsoft Graph endpoints by implementing new features\nand resolving technical issues. Authored and updated Microsoft Graph API\ndocumentation, contributing to the open-source GitHub repository.\nDeveloped and maintained features, addressed bugs, conducted pull\nrequest reviews, and deployed updates for the Microsoft Defender for Threat\nIntelligence (MDTI) application as a full-stack developer. \n\xa0 Page 1 of 4\xa0 \xa0\nUtilized Java and Spring Boot for backend development and React for frontend\nUI implementation.\nPerformed on-call responsibilities, including monitoring and responding to\nincidents via the Incident Response system. Have created and presented Post\nIncident Reviews (PIR) for the leadership team (LT).\nEnsured GDPR compliance by maintaining data classification standards for\ndata privacy.\nSenior Site Reliability Engineer (Security)\nJuly 2021\xa0-\xa0July 2023\xa0(2 years 1 month)\nAtlanta, Georgia, United States\nLed a cross-organizational project to integrate a multi-level detection\nauthoring framework and hosting service with a security information and event\nmanagement (SIEM) into the Azure China Sovereign Cloud.\nEngineered real-time AI/ML inference capabilities by collaborating with\ndata scientists to develop an Azure Function that streamed live data into\nan AzureML model. Optimized Kusto Query Language (KQL) queries and\nprovisioned essential infrastructure, ensuring synchronized data delivery for\naccurate, live predictions\nCollaborated with air-gapped Government Cloud engineering teams to ensure\ ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://0f0acbdb9ec5f44064.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0f0acbdb9ec5f44064.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold a patent. My focus has primarily been on software engineering, project management, and delivering innovative solutions in the fintech space rather than patent development. However, I continuously explore new ideas and technologies that could potentially lead to future innovations. If you have any specific questions about my work or projects, I’d be happy to discuss them!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The Agent's response is excellent. It is professional and engaging, and correctly states that Vincent Stoessel does not hold a patent based on the provided context. The response also opens the door for further discussion.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://1604caab3b04cd5d20.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1604caab3b04cd5d20.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Failed evaluation - retrying
# The agent's response is nonsensical and unprofessional. The agent also shouldn't be using pig latin.
# Passed evaluation - returning reply
